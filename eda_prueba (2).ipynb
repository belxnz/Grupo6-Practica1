# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn import datasets
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore') # Para evitar los molestos avisos.
# %matplotlib inline

# %%
df_train = pd.read_csv('/content/disp_st6ns1.txt')
df_train.head(3650)
# Out:
#      Unnamed: 0  apcp_sf1_1  apcp_sf2_1  apcp_sf3_1  apcp_sf4_1  apcp_sf5_1  \
# 0            V1    0.000000    0.000000    0.000000    0.000000    0.000000
# 1            V2    0.000000    0.000909    0.127273    0.000909    0.000000
# 2            V3    0.000000    0.000000    0.000000    0.000000    0.000000
# 3            V4    0.000000    0.000000    0.000000    0.000000    0.000000
# 4            V5    0.000000    0.000000    0.000000    0.000000    0.000000
# ...         ...         ...         ...         ...         ...         ...
# 2636      V2637    0.000000    0.000000    0.000000    0.000000    0.000000
# 2637      V2638    0.023636    0.073636    0.078182    0.000000    0.000000
# 2638      V2639    0.046364    0.083636    0.290000    0.094545    0.334545
# 2639      V2640    0.178182    0.191818    0.259091    0.003636    0.006364
# 2640      V2641    0.000000    0.003636    0.004545    0.000000    0.000000
#
#       dlwrf_s1_1  dlwrf_s2_1  dlwrf_s3_1  dlwrf_s4_1  ...  ulwrf_t2_1  \
# 0     234.401764  229.968914  234.719940  254.104944  ...  233.140839
# 1     276.634960  272.369578  268.436640  256.169015  ...  226.094627
# 2     218.280002  218.450567  226.860365  255.074577  ...  228.465100
# 3     232.681230  208.987453  213.493584  236.729101  ...  234.644049
# 4     248.980929  251.472505  259.123549  288.395427  ...  232.706659
# ...          ...         ...         ...         ...  ...         ...
# 2636  287.166196  277.219496  284.653215  312.463473  ...  239.835660
# 2637  287.795152  334.237319  323.103288  315.553167  ...  237.752398
# 2638  303.520696  291.848816  298.944461  328.155742  ...  226.737959
# 2639  297.920216  283.911410  280.051239  271.933849  ...  181.166185
# 2640  235.126726  242.498011  251.134030  272.861303  ...  228.900355
#
#       ulwrf_t3_1  ulwrf_t4_1  ulwrf_t5_1  uswrf_s1_1  uswrf_s2_1  uswrf_s3_1  \
# 0     237.578452  256.342403  245.431481           0    4.000000   41.636364
# 1     230.027276  248.015693  252.598371           0    3.818182   33.545455
# 2     233.935296  255.359149  253.256739           0    4.000000   41.727273
# 3     238.489481  255.291218  249.140133           0    4.000000   44.000000
# 4     236.589168  252.491824  254.837047           0    3.818182   39.454545
# ...          ...         ...         ...         ...         ...         ...
# 2636  254.345397  289.375658  288.845165           0   31.909091   80.545455
# 2637  244.625345  268.216972  266.884860           0   11.909091   60.000000
# 2638  236.628576  247.981893  240.346361           0   25.727273   69.363636
# 2639  197.439127  245.164397  247.458922           0   17.181818   61.454545
# 2640  237.242416  260.016349  258.497065           0   32.454000         NaN
#
#       uswrf_s4_1  uswrf_s5_1      salida
# 0     104.454545   71.636364  10116900.0
# 1      99.272727   71.818182   9262800.0
# 2     105.000000   73.636364  10789800.0
# 3     108.090909   74.909091  11816700.0
# 4      99.727273   70.545455   9936300.0
# ...          ...         ...         ...
# 2636  150.727273  126.727273  21756300.0
# 2637  145.727273  121.727273  18334800.0
# 2638  130.818182  103.545455  10785600.0
# 2639  149.181818  123.000000  13474500.0
# 2640         NaN         NaN         NaN
#
# [2641 rows x 77 columns]

# %%
df_train.columns
# Out:
# Index(['Unnamed: 0', 'apcp_sf1_1', 'apcp_sf2_1', 'apcp_sf3_1', 'apcp_sf4_1',
#        'apcp_sf5_1', 'dlwrf_s1_1', 'dlwrf_s2_1', 'dlwrf_s3_1', 'dlwrf_s4_1',
#        'dlwrf_s5_1', 'dswrf_s1_1', 'dswrf_s2_1', 'dswrf_s3_1', 'dswrf_s4_1',
#        'dswrf_s5_1', 'pres_ms1_1', 'pres_ms2_1', 'pres_ms3_1', 'pres_ms4_1',
#        'pres_ms5_1', 'pwat_ea1_1', 'pwat_ea2_1', 'pwat_ea3_1', 'pwat_ea4_1',
#        'pwat_ea5_1', 'spfh_2m1_1', 'spfh_2m2_1', 'spfh_2m3_1', 'spfh_2m4_1',
#        'spfh_2m5_1', 'tcdc_ea1_1', 'tcdc_ea2_1', 'tcdc_ea3_1', 'tcdc_ea4_1',
#        'tcdc_ea5_1', 'tcolc_e1_1', 'tcolc_e2_1', 'tcolc_e3_1', 'tcolc_e4_1',
#        'tcolc_e5_1', 'tmax_2m1_1', 'tmax_2m2_1', 'tmax_2m3_1', 'tmax_2m4_1',
#        'tmax_2m5_1', 'tmin_2m1_1', 'tmin_2m2_1', 'tmin_2m3_1', 'tmin_2m4_1',
#        'tmin_2m5_1', 'tmp_2m_1_1', 'tmp_2m_2_1', 'tmp_2m_3_1', 'tmp_2m_4_1',
#        'tmp_2m_5_1', 'tmp_sfc1_1', 'tmp_sfc2_1', 'tmp_sfc3_1', 'tmp_sfc4_1',
#        'tmp_sfc5_1', 'ulwrf_s1_1', 'ulwrf_s2_1', 'ulwrf_s3_1', 'ulwrf_s4_1',
#        'ulwrf_s5_1', 'ulwrf_t1_1', 'ulwrf_t2_1', 'ulwrf_t3_1', 'ulwrf_t4_1',
#        'ulwrf_t5_1', 'uswrf_s1_1', 'uswrf_s2_1', 'uswrf_s3_1', 'uswrf_s4_1',
#        'uswrf_s5_1', 'salida'],
#       dtype='object')

# %% [markdown]
# Como parte de este proyecto, se nos pide realizar un estudio sobre la correlación que existe entre las variable proporcionadas y la varible 'salida' cuyo valor numerico se proporciona tan solo para los 10 primeros años de estudio, para nosotros hallar la funcion que, a partir de las otras variables, predice un valor aproximado para salida, y probrar dicha funcion en los 2 años de estudio restantes.
# Por ello, de momento nos vamos a fijar unicamente en la variable 'salida', ya que es la variable objetivo de nuestros datos.

# %%
df_train['salida'].describe()
# Out:
# count    4.380000e+03
# mean     1.749081e+07
# std      7.945135e+06
# min      3.000000e+02
# 25%      1.135185e+07
# 50%      1.741605e+07
# 75%      2.459130e+07
# max      3.225630e+07
# Name: salida, dtype: float64

# %%
sns.distplot(df_train['salida']);

# %% [markdown]
# A simple vista podemos observar que hay una desviacion en relaciona a una distribucion normal. Tambien observamos que hay dos picos

# %%
# Asimetría y curtosis:

print("Skewness: %f" % df_train['salida'].skew())
print("Kurtosis: %f" % df_train['salida'].kurt())
# Out:
# Skewness: -0.125917
# Kurtosis: -1.054102

# %% [markdown]
# Ahora vamos a estudiar la relacion de 'salida' con las otras variables proporcionadas. Tras entender lo que significa cada una de ellas y que cada una corresponde a una hora del día distinta, creemos que las variables que más influyen sobre el resultado de 'salida' son dswrf_sfc ya que se trata de la media del flujo radiativo de onda corta que llega desde el cielo a la sufercifie(descendiente), es decir, en donde se encuentran las plantas energéticas, ya que la radiacion de onda corta contiene un nivel más alto de energía que la de onda larga, y por lo tanto influye en mayor medida en 'salida'. En cuanto a la hora, creemos que el que más influye sería aquellas horas que corresponden a la tarde, pues es cuando la temperatura suele ser la más alta (2 y 3 correspondientes a las 15h y 18h).

# %%
var1 = 'dswrf_s2_1'
var2 = 'dswrf_s3_1'
data = pd.concat([df_train['salida'], df_train[var1]], axis=1)
data.plot.scatter(x=var1, y='salida', alpha = 0.5);

data = pd.concat([df_train['salida'], df_train[var2]], axis=1)
data.plot.scatter(x=var2, y='salida', alpha = 0.5);

# %% [markdown]
# Ahora vamos a estudiar la correlacion entre todas las variables de la practica:

# %%
# Matriz de correlación:

corrmat = df_train.corr().abs()
f, ax = plt.subplots(figsize=(20, 20))
sns.heatmap(corrmat, vmax=1, square=True);

# %% [markdown]
# Tras ver la matriz de correlacion entre todas las variables, podemos llegar a las siguientes conclusiones:
# 1. Notamos que hay varias variables con un nivel de correlación mayor a 0.8 entre ellas, lo cual nos quiere decir que aportan información muy similar y que lo apropiado sería eliminarlas hasta que quede una. Este nivel alto lo podemos ver entre las siguientes variables:

# %%
def collinear_features(x, threshold):

    # Calculate the correlation matrix
    corr_matrix = x.corr()
    iters = range(len(corr_matrix.columns) - 1)
    drop_cols = []

    # Iterate through the correlation matrix and compare correlations
    for i in iters:
        for j in range(i+1):
            item = corr_matrix.iloc[j:(j+1), (i+1):(i+2)]
            col = item.columns
            row = item.index
            val = abs(item.values)

            # If correlation exceeds the threshold
            if val >= threshold and col.values[0] not in drop_cols:
                # Print the correlated features and the correlation value
                #print(col.values[0], "|", row.values[0], "|", round(val[0][0], 2))
                drop_cols.append(col.values[0])

    # Drop one of each pair of correlated columns
    return drop_cols

var=collinear_features(df_train, 0.95)
print(var)
# Out:
# ['dlwrf_s2_1', 'dlwrf_s3_1', 'dlwrf_s4_1', 'dlwrf_s5_1', 'dswrf_s3_1', 'dswrf_s5_1', 'pres_ms2_1', 'pres_ms3_1', 'pres_ms4_1', 'pres_ms5_1', 'pwat_ea2_1', 'pwat_ea3_1', 'pwat_ea4_1', 'pwat_ea5_1', 'spfh_2m2_1', 'spfh_2m3_1', 'spfh_2m4_1', 'spfh_2m5_1', 'tcolc_e1_1', 'tcolc_e2_1', 'tcolc_e3_1', 'tcolc_e4_1', 'tcolc_e5_1', 'tmax_2m2_1', 'tmax_2m3_1', 'tmax_2m4_1', 'tmax_2m5_1', 'tmin_2m1_1', 'tmin_2m2_1', 'tmin_2m3_1', 'tmin_2m4_1', 'tmin_2m5_1', 'tmp_2m_1_1', 'tmp_2m_2_1', 'tmp_2m_3_1', 'tmp_2m_4_1', 'tmp_2m_5_1', 'tmp_sfc1_1', 'tmp_sfc2_1', 'tmp_sfc3_1', 'tmp_sfc4_1', 'tmp_sfc5_1', 'ulwrf_s1_1', 'ulwrf_s2_1', 'ulwrf_s3_1', 'ulwrf_s4_1', 'ulwrf_s5_1', 'ulwrf_t3_1', 'ulwrf_t5_1', 'uswrf_s2_1']

# %% [markdown]
# Tambien podemos estududiar cuales son las variables que estan más relacionadas con la variable 'salida':

# %%
corr = df_train.corr()
corr[['salida']].sort_values(by = 'salida',ascending = False).style.background_gradient()
# Out:
# <style type="text/css">
# #T_d04fa_row0_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_d04fa_row1_col0, #T_d04fa_row2_col0 {
#   background-color: #034f7d;
#   color: #f1f1f1;
# }
# #T_d04fa_row3_col0 {
#   background-color: #03517e;
#   color: #f1f1f1;
# }
# #T_d04fa_row4_col0 {
#   background-color: #045788;
#   color: #f1f1f1;
# }
# #T_d04fa_row5_col0 {
#   background-color: #04598c;
#   color: #f1f1f1;
# }
# #T_d04fa_row6_col0 {
#   background-color: #045e93;
#   color: #f1f1f1;
# }
# #T_d04fa_row7_col0 {
#   background-color: #046096;
#   color: #f1f1f1;
# }
# #T_d04fa_row8_col0, #T_d04fa_row9_col0 {
#   background-color: #046097;
#   color: #f1f1f1;
# }
# #T_d04fa_row10_col0 {
#   background-color: #046299;
#   color: #f1f1f1;
# }
# #T_d04fa_row11_col0 {
#   background-color: #04629a;
#   color: #f1f1f1;
# }
# #T_d04fa_row12_col0 {
#   background-color: #04639b;
#   color: #f1f1f1;
# }
# #T_d04fa_row13_col0 {
#   background-color: #04649e;
#   color: #f1f1f1;
# }
# #T_d04fa_row14_col0 {
#   background-color: #05659f;
#   color: #f1f1f1;
# }
# #T_d04fa_row15_col0, #T_d04fa_row16_col0 {
#   background-color: #0566a0;
#   color: #f1f1f1;
# }
# #T_d04fa_row17_col0, #T_d04fa_row18_col0, #T_d04fa_row19_col0 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_d04fa_row20_col0, #T_d04fa_row21_col0 {
#   background-color: #0568a3;
#   color: #f1f1f1;
# }
# #T_d04fa_row22_col0, #T_d04fa_row23_col0 {
#   background-color: #0569a5;
#   color: #f1f1f1;
# }
# #T_d04fa_row24_col0 {
#   background-color: #056aa6;
#   color: #f1f1f1;
# }
# #T_d04fa_row25_col0, #T_d04fa_row26_col0 {
#   background-color: #056caa;
#   color: #f1f1f1;
# }
# #T_d04fa_row27_col0 {
#   background-color: #056dab;
#   color: #f1f1f1;
# }
# #T_d04fa_row28_col0 {
#   background-color: #056ead;
#   color: #f1f1f1;
# }
# #T_d04fa_row29_col0 {
#   background-color: #0d75b3;
#   color: #f1f1f1;
# }
# #T_d04fa_row30_col0, #T_d04fa_row31_col0, #T_d04fa_row32_col0 {
#   background-color: #1278b4;
#   color: #f1f1f1;
# }
# #T_d04fa_row33_col0, #T_d04fa_row34_col0, #T_d04fa_row35_col0 {
#   background-color: #157ab5;
#   color: #f1f1f1;
# }
# #T_d04fa_row36_col0 {
#   background-color: #197db7;
#   color: #f1f1f1;
# }
# #T_d04fa_row37_col0 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_d04fa_row38_col0, #T_d04fa_row39_col0 {
#   background-color: #2987bc;
#   color: #f1f1f1;
# }
# #T_d04fa_row40_col0 {
#   background-color: #2a88bc;
#   color: #f1f1f1;
# }
# #T_d04fa_row41_col0 {
#   background-color: #3f93c2;
#   color: #f1f1f1;
# }
# #T_d04fa_row42_col0 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_d04fa_row43_col0, #T_d04fa_row44_col0 {
#   background-color: #4a98c5;
#   color: #f1f1f1;
# }
# #T_d04fa_row45_col0 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
# }
# #T_d04fa_row46_col0 {
#   background-color: #509ac6;
#   color: #f1f1f1;
# }
# #T_d04fa_row47_col0 {
#   background-color: #5a9ec9;
#   color: #f1f1f1;
# }
# #T_d04fa_row48_col0 {
#   background-color: #60a1ca;
#   color: #f1f1f1;
# }
# #T_d04fa_row49_col0 {
#   background-color: #62a2cb;
#   color: #f1f1f1;
# }
# #T_d04fa_row50_col0 {
#   background-color: #6ba5cd;
#   color: #f1f1f1;
# }
# #T_d04fa_row51_col0 {
#   background-color: #6fa7ce;
#   color: #f1f1f1;
# }
# #T_d04fa_row52_col0 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_d04fa_row53_col0 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_d04fa_row54_col0 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_d04fa_row55_col0 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_d04fa_row56_col0 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_d04fa_row57_col0 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_d04fa_row58_col0, #T_d04fa_row59_col0 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_d04fa_row60_col0 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_d04fa_row61_col0, #T_d04fa_row62_col0 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_d04fa_row63_col0 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_d04fa_row64_col0, #T_d04fa_row65_col0, #T_d04fa_row66_col0, #T_d04fa_row67_col0 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_d04fa_row68_col0, #T_d04fa_row69_col0 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_d04fa_row70_col0, #T_d04fa_row71_col0, #T_d04fa_row72_col0, #T_d04fa_row73_col0 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_d04fa_row74_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_d04fa_row75_col0 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d04fa" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d04fa_level0_col0" class="col_heading level0 col0" >salida</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d04fa_level0_row0" class="row_heading level0 row0" >salida</th>
#       <td id="T_d04fa_row0_col0" class="data row0 col0" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d04fa_level0_row1" class="row_heading level0 row1" >dswrf_s3_1</th>
#       <td id="T_d04fa_row1_col0" class="data row1 col0" >0.877270</td>
#     </tr>
#     <tr>
#       <th id="T_d04fa_level0_row2" class="row_heading level0 row2" >dswrf_s5_1</th>
#       <td id="T_d04fa_row2_col0" class="data row2 col0" >0.876034</td>
#     </tr>
#     <tr>
#       <th id="T_d04fa_level0_row3" class="row_heading level0 row3" >dswrf_s4_1</th>
#       <td id="T_d04fa_row3_col0" class="data row3 col0" >0.873229</td>
#     </tr>
#     <tr>
#       <th id="T_d04fa_level0_row4" class="row_heading level0 row4" >uswrf_s2_1</th>
#       <td id="T_d04fa_row4_col0" class="data row4 col0" >0.842086</td>
#     </tr>
#     <tr>
#       <th id="T_d04fa_level0_row5" class="row_heading level0 row5" >dswrf_s2_1</th>
#       <td id="T_d04fa_row5_col0" class="data row5 col0" >0.829018</td>
#     </tr>
#     <tr>
#       <th id="T_d04fa_level0_row6" class="row_heading level0 row6" >uswrf_s3_1</th>
#       <td id="T_d04fa_row6_col0" class="data row6 col0" >0.798940</td>
#     </tr>
#     <tr>
#       <th id="T_d04fa_level0_row7" class="row_heading level0 row7" >ulwrf_s5_1</th>
#       <td id="T_d04fa_row7_col0" class="data row7 col0" >0.778697</td>
#     </tr>
#     <tr>
#       <th id="T_d04fa_level0_row8" class="row_heading level0 row8" >tmp_sfc4_1</th>
#       <td id="T_d04fa_row8_col0" class="data row8 col0" >0.777438</td>
#     </tr>
#     <tr>
#       <th id="T_d04fa_level0_row9" class="row_heading level0 row9" >ulwrf_s4_1</th>
#       <td id="T_d04fa_row9_col0" class="data row9 col0" >0.775706</td>
#     </tr>
#     <tr>
#       <th id="T_d04fa_level0_row10" class="row_heading level0 row10" >tmp_sfc3_1</th>
#       <td id="T_d04fa_row10_col0" class="data row10 col0" >0.764191</td>
#     </tr>
#     <tr>
#       <th id="T_d04fa_level0_row11" class="row_heading level0 row11" >tmp_sfc5_1</th>
#       <td id="T_d04fa_row11_col0" class="data row11 col0" >0.757148</td>
#     </tr>
#     <tr>
#       <th id="T_d04fa_level0_row12" class="row_heading level0 row12" >tmp_2m_5_1</th>
#       <td id="T_d04fa_row12_col0" class="data row12 col0" >0.754243</td>
#     </tr>
#     <tr>
#       <th id="T_d04fa_level0_row13" class="row_heading level0 row13" >tmin_2m5_1</th>
#       <td id="T_d04fa_row13_col0" class="data row13 col0" >0.742482</td>
#     </tr>
#     <tr>
#       <th id="T_d04fa_level0_row14" class="row_heading level0 row14" >tmp_2m_4_1</th>
#       <td id="T_d04fa_row14_col0" class="data row14 col0" >0.735249</td>
#     </tr>
#     <tr>
#       <th id="T_d04fa_level0_row15" class="row_heading level0 row15" >tmax_2m5_1</th>
#       <td id="T_d04fa_row15_col0" class="data row15 col0" >0.732123</td>
#     </tr>
#     <tr>
#       <th id="T_d04fa_level0_row16" class="row_heading level0 row16" >tmax_2m4_1</th>
#       <td id="T_d04fa_row16_col0" class="data row16 col0" >0.730733</td>
#     </tr>
#     <tr>
#       <th id="T_d04fa_level0_row17" class="row_heading level0 row17" >tmin_2m4_1</th>
#       <td id="T_d04fa_row17_col0" class="data row17 col0" >0.723187</td>
#     </tr>
#     <tr>
#       <th id="T_d04fa_level0_row18" class="row_heading level0 row18" >tmp_2m_3_1</th>
#       <td id="T_d04fa_row18_col0" class="data row18 col0" >0.718565</td>
#     </tr>
#     <tr>
#       <th id="T_d04fa_level0_row19" class="row_heading level0 row19" >ulwrf_s3_1</th>
#       <td id="T_d04fa_row19_col0" class="data row19 col0" >0.718563</td>
#     </tr>

# %% [markdown]
# En las matrices de correlacion se puede observar lo siguiente, considerando 0.75 el valor minimo de correlación para considerar una variable lo suficientemente influencial sobre 'salida':
# 1. Las variables dswrf_sfc son las que más correlacion tienen con la varible 'salida' y se corresponden a la media del flujo de radiación de onda corta que llega del cielo en la superficie (descendiente), más especificamente a las horas 2,3,4,5 (12h, 15h, 18h y 24h respectivamente)
# 2. Las variables uswrf_sfc que corresponde a la radiacion de onda corta que procede del suelo (ascendentes) sobre la superficie a las horas 2 y 3 también tienen un alto nivel de correlación.
# 3. A la hora 5, la variable ulwrf_sfc que corresponde a la radiacion de onda larga que procede del suelo sobre la superficie tiene alta correlacion con 'salida'.
# 4. Finalmente, la temperatura de la superficie (tmp_sfc, a las horas 3,4 y 5) y la temperatura a dos metros por encima de la superficie (tmp_2m a la hora 5) tienen ina alta correlacion con 'salida'.
